# %% [markdown]
# # Beautiful Soup Tutorial
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, para ello existe web scraping. El web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En primer lugar sería necesario instalar la librería *bautifulsoup4*.

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\merlo\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\merlo\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Seguidamente, también es necesario instalar un parser, teniendo que utilizar el *lxml* ya que es el mas rápido.

# %%
# %pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\merlo\anaconda3\lib\site-packages (4.9.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de *requests*. Con *requests* podemos solicitar páginas web de sitios web.

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\merlo\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\merlo\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\merlo\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\merlo\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\merlo\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Mi primer scraping
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.madrid.org/filmmadrid/en/company-directory.html?id=5"

response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
# Para ver el contenido
response.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n  <head>\n    <meta charset="utf-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <title>Companies Directory  of the Madrid Region</title>\n        <meta name="description" content="Film Madrid \xe2\x80\x93 Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid.">\n        <link rel="canonical" href="www.madrid.org/filmmadrid/en/company-directory.html" />\n\n        <!-- FACEBOOK METAS -->\n        <meta property="og:title" content="Film Madrid - Filming Promotion Office of the Madrid Region" />\n        <meta property="og:description" content="Film Madrid \xe2\x80\x93 Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." />\n        <meta property="og:site_name" content="Film Madrid - Filming Promotion Office of the Madrid Region" />\n        <meta property="og:url" content="www.madrid.org/filmmadrid/en/company-directory.html" />\n\n        <!-- TWITTER METAS -->\n        <meta property="twitter:title" content="Film Madrid - Filming Promotion Office of the Madrid Region" />\n        <meta property="twitter:description" content="Film Madrid \xe2\x80\x93 Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." />\n\n        <!-- FAVICON -->\n        <link href="../favicon.ico" rel="shortcut icon" type="image/x-icon" />\n\n\n        <!--tipografias-->\n        <link href=\'https://fonts.googleapis.com/css?family=Montserrat:200,400,700\' rel=\'stylesheet\' type=\'text/css\'>\n        <link href=\'https://fonts.googleapis.com/css?family=Oswald:400,300,700\' rel=\'stylesheet\' type=\'text/css\'>\n\n        <!-- css-->\n        <link rel="stylesheet" href="../css/bootstrap.min.css">\n        <link rel="stylesheet" href="../css/all.min.css">\n        <link rel="stylesheet" href="../css/main2.min.css">\n\n  </head>\n\n\n  <body id="rutas-cine" class="interior directorio-profesionales">\n\n   <!--cabecera-->\n\n    <header itemscope="itemscope" itemtype="http://schema.org/WPHeader" class="head-main">\n      \n        <div class="container-fluid d-flex justify-content-between">\n          <a itemscope="itemscope" itemtype="http://schema.org/Organization" class="navbar-brand d-flex align-items-center" href="index.html">\n            <img itemprop="logo" src="../imagenes/interfaz/logo_film_madrid.png" alt="Logotipo Film Madrid"  class="img-fluid">\n          </a>\n          <div class="d-inline-flex align-items-right logos-bandera">\n            <div class="d-inline-flex align-items-right ev">\n                  <div class=""><a href="../index.html"><img src="../imagenes/interfaz/bandera-espanol.jpg" class="bandera"></a></div>\n                  <div class="texto-ev"><a href="../index.html">Versi\xc3\xb3n<br>en espa\xc3\xb1ol</a></div>\n               </div>\n                <a href="https://www.comunidad.madrid/servicios/informacion-atencion-ciudadano" target="blank" title="Este enlace abrir\xc3\xa1 una ventana nueva"><img src="../imagenes/interfaz/logo_012.png" class="img012" alt="Comunidad de Madrid - 012"></a>\n                <a href="https://www.comunidad.madrid/" target="blank" title="Este enlace abrir\xc3\xa1 una ventana nueva"><img src="../imagenes/interfaz/logo_cam.png" class="img012" alt="Comunidad de Madrid"></a>\n                </div>\n            </div>\n\n              <nav class="navbar navbar-expand-lg  ">\n                 \n                  <button class="navbar-toggler" type="button" data-toggle="collapse" data-targe ...

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n  <head>\n    <meta charset="utf-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <title>Companies Directory  of the Madrid Region</title>\n        <meta name="description" content="Film Madrid \xe2\x80\x93 Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid.">\n        <link rel="canonical" href="www.madrid.org/filmmadrid/en/company-directory.html" />\n\n        <!-- FACEBOOK METAS -->\n        <meta property="og:title" content="Film Madrid - Filming Promotion Office of the Madrid Region" />\n        <meta property="og:description" content="Film Madrid \xe2\x80\x93 Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." />\n        <meta property="og:site_name" content="Film Madrid - Filming Promotion Office of the Madrid Region" />\n        <meta property="og:url" content="www.madrid.org/filmmadrid/en/company-directory.html" />\n\n        <!-- TWITTER METAS -->\n        <meta property="twitter:title" content="Film Madrid - Filming Promotion Office of the Madrid Region" />\n        <meta property="twitter:description" content="Film Madrid \xe2\x80\x93 Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." />\n\n        <!-- FAVICON -->\n        <link href="../favicon.ico" rel="shortcut icon" type="image/x-icon" />\n\n\n        <!--tipografias-->\n        <link href=\'https://fonts.googleapis.com/css?family=Montserrat:200,400,700\' rel=\'stylesheet\' type=\'text/css\'>\n        <link href=\'https://fonts.googleapis.com/css?family=Oswald:400,300,700\' rel=\'stylesheet\' type=\'text/css\'>\n\n        <!-- css-->\n        <link rel="stylesheet" href="../css/bootstrap.min.css">\n        <link rel="stylesheet" href="../css/all.min.css">\n        <link rel="stylesheet" href="../css/main2.min.css">\n\n  </head>\n\n\n  <body id="rutas-cine" class="interior directorio-profesionales">\n\n   <!--cabecera-->\n\n    <header itemscope="itemscope" itemtype="http://schema.org/WPHeader" class="head-main">\n      \n        <div class="container-fluid d-flex justify-content-between">\n          <a itemscope="itemscope" itemtype="http://schema.org/Organization" class="navbar-brand d-flex align-items-center" href="index.html">\n            <img itemprop="logo" src="../imagenes/interfaz/logo_film_madrid.png" alt="Logotipo Film Madrid"  class="img-fluid">\n          </a>\n          <div class="d-inline-flex align-items-right logos-bandera">\n            <div class="d-inline-flex align-items-right ev">\n                  <div class=""><a href="../index.html"><img src="../imagenes/interfaz/bandera-espanol.jpg" class="bandera"></a></div>\n                  <div class="texto-ev"><a href="../index.html">Versi\xc3\xb3n<br>en espa\xc3\xb1ol</a></div>\n               </div>\n                <a href="https://www.comunidad.madrid/servicios/informacion-atencion-ciudadano" target="blank" title="Este enlace abrir\xc3\xa1 una ventana nueva"><img src="../imagenes/interfaz/logo_012.png" class="img012" alt="Comunidad de Madrid - 012"></a>\n                <a href="https://www.comunidad.madrid/" target="blank" title="Este enlace abrir\xc3\xa1 una ventana nueva"><img src="../imagenes/interfaz/logo_cam.png" class="img012" alt="Comunidad de Madrid"></a>\n                </div>\n            </div>\n\n              <nav class="navbar navbar-expand-lg  ">\n                 \n                  <button class="navbar-toggler" type="button" data-toggle="collapse" data-targe ...

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "html.parser")

#tuve un problema con uv y lxml

# %% [markdown]
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML)
#
# El segundo parámetro ('html.parser'), es el parser que se usa en html

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Companies Directory  of the Madrid Region</title>
# <meta content="Film Madrid – Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." name="description"/>
# <link href="www.madrid.org/filmmadrid/en/company-directory.html" rel="canonical"/>
# <!-- FACEBOOK METAS -->
# <meta content="Film Madrid - Filming Promotion Office of the Madrid Region" property="og:title">
# <meta content="Film Madrid – Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." property="og:description">
# <meta content="Film Madrid - Filming Promotion Office of the Madrid Region" property="og:site_name">
# <meta content="www.madrid.org/filmmadrid/en/company-directory.html" property="og:url">
# <!-- TWITTER METAS -->
# <meta content="Film Madrid - Filming Promotion Office of the Madrid Region" property="twitter:title"/>
# <meta content="Film Madrid – Region of Madrid Filming Promotion Office, a public service whose goal is to support the audio-visual industry in Madrid." property="twitter:description"/>
# <!-- FAVICON -->
# <link href="../favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!--tipografias-->
# <link href="https://fonts.googleapis.com/css?family=Montserrat:200,400,700" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Oswald:400,300,700" rel="stylesheet" type="text/css"/>
# <!-- css-->
# <link href="../css/bootstrap.min.css" rel="stylesheet"/>
# <link href="../css/all.min.css" rel="stylesheet"/>
# <link href="../css/main2.min.css" rel="stylesheet"/>
# </meta></meta></meta></meta></head>
# <body class="interior directorio-profesionales" id="rutas-cine">
# <!--cabecera-->
# <header class="head-main" itemscope="itemscope" itemtype="http://schema.org/WPHeader">
# <div class="container-fluid d-flex justify-content-between">
# <a class="navbar-brand d-flex align-items-center" href="index.html" itemscope="itemscope" itemtype="http://schema.org/Organization">
# <img alt="Logotipo Film Madrid" class="img-fluid" itemprop="logo" src="../imagenes/interfaz/logo_film_madrid.png"/>
# </a>
# <div class="d-inline-flex align-items-right logos-bandera">
# <div class="d-inline-flex align-items-right ev">
# <div class=""><a href="../index.html"><img class="bandera" src="../imagenes/interfaz/bandera-espanol.jpg"/></a></div>
# <div class="texto-ev"><a href="../index.html">Versión<br/>en español</a></div>
# </div>
# <a href="https://www.comunidad.madrid/servicios/informacion-atencion-ciudadano" target="blank" title="Este enlace abrirá una ventana nueva"><img alt="Comunidad de Madrid - 012" class="img012" src="../imagenes/interfaz/logo_012.png"/></a>
# <a href="https://www.comunidad.madrid/" target="blank" title="Este enlace abrirá una ventana nueva"><img alt="Comunidad de Madrid" class="img012" src="../imagenes/interfaz/logo_cam.png"/></a>
# </div>
# </div>
# <nav class="navbar navbar-expand-lg">
# <button aria-controls="navbarNavDropdown" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNavDropdown" data-toggle="collapse" type="button">
# <i class="fas fa-bars"></i>
# </button>
# <div class="collapse navbar-collapse" id="navbarNavDropdown">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="menu_localizaciones" role="button">FILMING LOCATIONS</a>
# <div aria-labelledby="menu_localizaciones" class="dropdown-menu">
# <a class="dropdown-item" href="filming-locations.html">Search locations  </a>
# <a class="dropdown-item" href="locations-catalog-2022.html">Catalogue 2022 </a>
# <a class="dropdown-item" href="filming-location-proposals.html">Catalogue 2021 </a>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="menu_directorio" role="button">PROFESSIONAL  DIRECTORY</a>
# <div aria-labelledby="menu_directorio" class="dropdown-menu">
# <a class="dropdown-item" href="company-directory.html">Companies Directory </a>
# <a class="dropdown-item" href="professionals-directory.html">Professionals Directory   </a>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="rodar-en-la-comunidad-de-madrid.html" id="menu_rodar" role="button">FILMING IN MADRID </a>
# <div aria-labelledby="menu_rodar" class="dropdown-menu">
# <a class="dropdown-item" href="filming-in-the-region-of-madrid.html">Filming in the region of Madrid   </a>
# <a class="dropdown-item" href="international-shoots.html">International Shoots </a>
# <a class="dropdown-item" href="safe-shootings-covid.html">Filming with COVID-19 </a>
# <!--<a class="dropdown-item" href="#">International productions </a>-->
# <a class="dropdown-item" href="sustainable-filming.html">Sustainable filming  </a>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="menu_audiovisual" role="button">AUDIOVISUAL INDUSTRY  </a>
# <div aria-labelledby="menu_audiovisual" class="dropdown-menu">
# <a class="dropdown-item" href="audio-visual-in-the-community-of-madrid.html">Audiovisual industry in the region of Madrid    </a>
# <a class="dropdown-item" href="subsidies-for-the-audio-visual-sector.html">Film  funds     </a>
# <a class="dropdown-item" href="tax-incentives.html">Tax incentives   </a>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="menu_turismo" role="button">SCREEN TOURISM  </a>
# <div aria-labelledby="menu_turismo" class="dropdown-menu">
# <a class="dropdown-item" href="filmed-in-madrid.html">Filmed in Madrid    </a>
# <a class="dropdown-item" href="film-routes.html">Film Routes  </a>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="noticias.html">NEWS</a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="rodar-en-la-comunidad-de-madrid.html" id="menu_filmmadrid" role="button">FILM MADRID  </a>
# <div aria-labelledby="menu_filmmadrid" class="dropdown-menu">
# <a class="dropdown-item" href="about-film-madrid.html">About Film Madrid</a>
# <a class="dropdown-item" href="contact.html">Contact   </a>
# <a class="dropdown-item" href="film_madrid_forma.html">Film Madrid Forma   </a>
# <a class="dropdown-item" href="film-madrid-service.html">Film Madrid Service   </a>
# <a class="dropdown-item" href="videos-and-publications.html">Videos and publications   </a>
# </div>
# </li>
# <li class="nav-item link-idioma">
# <a class="nav-link" href="../index.html">VERSIÓN EN ESPAÑOL</a>
# </li>
# </ul>
# </div>
# </nav>
#  <!--navbar end-->
# <!--main-menu end-->
# </header>
# <section>
# <div class="page-header" style="background-image: url('../imagenes/contenido/paginas/directorio-profesional2.jpg')">
# <div class="carousel-caption d-none d-md-block">
# <h1 class="display-1">Companies Directory </h1>
# </div>
# </div>
# </section>
# <div class="container my-5">
# <div class="col-sm-12">
# <h1 class="display-5 d-md-none">Companies Directory </h1>
# <div class="textos_interiores">
# <p>
#             The Madrid Region offers the widest variety of professional services of proven experience and quality that can be found in Spain. Indeed, the Madrid Region is home to more than 1,500 companies linked to the audio-visual sector, including production and post-production companies, production services firms, distributors, companies specializing in animation and VFX, among many others.
#           </p>
# <div class="row mt-4">
# <div class="col-12 text-center">
# <a class="btn btn-info btn-lg" href="https://filmmadrid.com/alta-empresas.php" target="_blank" title="This link will open in a new window"><i class="fas fa-pencil-alt"></i> Register COMPANIES</a>
# </div>
# </div>
# <!--buscador-->
# <div class="card my-4">
# <div class="card-header">
#               Search our directory
#             </div>
# <div class="card-body py-2">
# <form class="abajo buscador">
# <div class="buscador_guia row">
# <div class="form-group col-md-5">
# <label sr-only="Búsqueda por palabras"></label>
# <input class="form-control palabra" id="palabra" name="q" placeholder="Write your search" type="text"/>
# </div>
# <div class="form-group col-md-5 selectContainer">
# <label sr-only="Category"></label>
# <select class="form-control" id="categorias_loc" name="id">
# <option value="">select a category</option>
# </select>
# </div>
# <div class="form-group col-md-2">
# <br/>
# <input class="btn btn-danger" type="submit" value="SEARCH"/>
# </div>
# </div>
# </form>
# </div>
# </div>
# <!--final buscador-->
# <!--resultados-->
# <div class="num_result" id="numero_resultados">
# </div>
# <!--final resultados-->
# <!--LISTADO DE RESULTADOS-->
# <div class="listado_resultados row" id="resultados">
# <div class="col-12 row" id="listaCategorias">
# <div class="col-12">
# <h2 class="mb-4">CATEGORIES</h2>
# </div>
# </div>
# </div>
# <!--FINAL DEL LISTADO DE RESULTADOS-->
# </div>
# </div>
# </div>
# <!--prefooter-->
# <div id="prefooter">
# <div class="container">
# <div class="row caja-prefooter">
# <div class="col-6 contacto">
# <img alt="Logotipo Film Madrid" class="img-fluid" itemprop="logo" src="../imagenes/interfaz/logo_film_madrid.png"/>
# <div class="datos-contacto">
# <a href="tel:+34 91 720 81 07">+34 91 720 81 07</a><br/>
# <a href="mailto:filmmadrid@madrid.org">
#                   filmmadrid@madrid.org
#                   </a>
# </div>
# </div>
# <div class="col-md-6 col-xs-12 siguenos">Follow us <a href="https://twitter.com/film_madrid" target="_blank" title="Este enlace se abrirá en una ventana nueva"><i class="fab fa-twitter"></i></a><a href="https://www.instagram.com/film.madrid/" target="_blank" title="Este enlace se abrirá en una ventana nueva"><i class="fab fa-instagram"></i></a> <a href="https://www.youtube.com/@ConsejeriadeCulturaMadrid" target="_blank" title="Este enlace se abrirá en una ventana nueva"><i class="fab fa-youtube"></i></a></div>
# </div>
# </div>
# </div>
# <!--final prefooter-->
# <footer>
# <div class="container">
# <div class="col-sm-6 col-xs-12">
# <a href="https://www.comunidad.madrid/servicios/atencion-ciudadano" target="_blank" title="This link will open in a new window">012</a>
#              -
#             <a href="https://www.bocm.es/" target="_blank" title="This link will open in a new window">BOCM</a>
#              -
#             <a href="https://www.comunidad.madrid/servicios/informacion-atencion-ciudadano/aviso-legal-privacidad">Disclaimer</a>
# <br/>
#             © 2023 COMUNIDAD DE MADRID
#           </div>
# <div class="col-xs-12 col-sm-6 miembrode">
#             MEMBER OF:
#             <a href="http://www.shootinginspain.info/index.php/es/" target="_blank" title="This link will open in a new window"><img alt="Spain Film Commission" src="../imagenes/interfaz/logo-sfc.png"/></a>
# <a href="https://eufcn.com/" target="_blank" title="Enlace a ventana nueva"><img alt="European Film Commission Network EUFCN" src="../imagenes/interfaz/logo_eufcn.png"/></a>
# <a href="http://www.afci.org/" target="_blank" title="This link will open in a new window"><img alt="Logo AFCI" src="../imagenes/interfaz/logo-afci.png"/></a>
# </div>
# </div>
# </footer>
# <!--SCRIPTS-->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js"></script>
# <script src="../js/bootstrap.min.js"></script>
# <script>
#       var idioma = 'es';
#       var esLocalizaciones = false;
#       var esProducciones = false;
#       var esMapa = false;
#     </script>
# <script src="../js/funciones.min.js"></script>
# <script src="../js/fetch.min.js"></script>
# <script type="text/javascript">
#       const pContain = document.getElementById('listaCategorias');
#       const selContain = document.getElementById('categorias_loc');
#       fetchurl = 'https://filmmadrid.com/api/empresas/directorio-en/';
#       //fetchurl = 'https://localhost/film_madrid/filmmadrid.com/api/empresas/directorio/';
#       sonEmpresas = false;
#
#       id = findGetParameter('id');
#       q = findGetParameter('q');
#
#       if ((id != '' && id != undefined) || (q != '' && q != undefined)) {
#         fetchurl2 = 'https://filmmadrid.com/api/empresas/';
#         //fetchurl2 = 'https://localhost/film_madrid/filmmadrid.com/api/empresas/';
#         sonEmpresas = true;
#
#         if (id != '' && id != undefined)
#           fetchurl2 = fetchurl2 + id + '/';
#
#         if (q != '' && q != undefined) {
#           fetchurl2 = fetchurl2 + '?q=' + q;
#           document.getElementById('palabra').value = q;
#         }
#
#       }
#
#       //console.log(fetchurl);
#
#       //Cargamos los resultados
#       fetch(fetchurl)
#         .then(r => {
#           return r.json()
#         })
#         .then(posts => {
#           posts.map(post => {
#             const pDiv = document.createElement('div');
#             pDiv.classList.add('col-12');
#             pDiv.classList.add('col-sm-4');
#             pDiv.classList.add('categoria-listado');
#
#             const pGroup = document.createElement('optgroup');
#             pGroup.setAttribute('label',post.tipo_en);
#
#             imagen = post.imagen;
#
#             estehtml = '<div class="caja_resultado"><img src="' + imagen + '" class="img-fluid"><h5>' + post.tipo_en + '</h5><ul>';
#
#             contador = 0;
#             post.categorias.forEach(function(categ) {
#               contador++;
#
#               estehtml += '<li><a href="company-directory.html?id=' + categ.id + '#resultados" class="categoria">' + categ.cat_en + '</li>';
#
#               if (contador == 9) {
#                   estehtml += '<li><a class="categoria" data-toggle="collapse" href="#desplegable_cat' + categ.id + '" role="button" aria-expanded="false" aria-controls="collapseExample"><strong>' + __('Ver más...','See more...') + '</strong></a></li><div class="collapse" id="desplegable_cat' + categ.id + '">';
#               }
#
#               const pOption = document.createElement('option');
#               pOption.text = categ.cat_en;
#               pOption.value = categ.id;
#
#               if (categ.id == id)
#                 pOption.setAttribute('selected','selected');
#               pGroup.appendChild(pOption);
#             });
#
#             if (contador>9)
#               estehtml += '</div>';
#
#             estehtml += '</ul></div></div>';
#
#             if (!sonEmpresas) {
#               pDiv.innerHTML = estehtml;
#               pContain.appendChild(pDiv);
#             }
#
#             selContain.appendChild(pGroup);
#           });
#         });
#
#         if (sonEmpresas) {
#           pContain.innerHTML = '';
#           fetch(fetchurl2)
#           .then(r => {
#             return r.json()
#           })
#           .then(posts => {
#             posts.map(post => {
#               //console.log(post);
#               const pDiv = document.createElement('div');
#               pDiv.classList.add('col-12');
#               pDiv.classList.add('resultado');
#
#               estehtml = "<h3>" + post.name + '</h3><div class="row caja_resultado"><div class="enlaces_redes col-sm-12">';
#
#               if ("" != post.fb)
#                  estehtml += '<a href="' + post.fb + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-facebook-f" aria-hidden="true"></i></a>';
#
#               if ("" != post.tw)
#                 estehtml += '<a href="' + post.tw + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-twitter" aria-hidden="true"></i></a>';
#
#               if ("" != post.vimeo)
#                 estehtml += '<a href="' + post.vimeo + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-vimeo" aria-hidden="true"></i></a>';
#
#               if ("" != post.lk)
#                 estehtml += '<a href="' + post.lk + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-linkedin" aria-hidden="true"></i></a>';
#
#               if ("" != post.yt)
#                 estehtml += '<a href="' + post.yt + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-youtube" aria-hidden="true"></i></a>';
#
#               if ('' != post.flickr)
#                 estehtml += '<a href="' + post.flickr + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-flickr" aria-hidden="true"></i></a>';
#
#               if ("" != post.ins)
#                 estehtml += '<a href="' + post.ins + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-instagram" aria-hidden="true"></i></a>';
#
#               if ("" != post.pin)
#                 estehtml += '<a href="' + post.pin + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fab fa-pinterest-p" aria-hidden="true"></i></a>';
#
#               if("" != post.blog)
#                 estehtml += '<a href="' + post.blog + '" class="redes" target="_blank" title="Enlace a ventana nueva"><i class="fa fa-rss" aria-hidden="true"></i></a>';
#
#               estehtml += '</div><div class="col-sm-5"><p>';
#
#               if ("" !== post.dir)
#                 estehtml += post.dir + '. ' + post.cp + " " + post.pob + "<br>";
#
#               if ("" !== post.tel)
#                 estehtml += '<i class="fa fa-phone"></i> <a href="tel:+' + post.tel + '">' + post.tel + "</a>";
#
#               if ("" !== post.tel && "" !== post.tel2)
#                 estehtml += " - ";
#
#               if ("" !== post.tel2)
#                 estehtml += '<a href="tel:+' + post.tel2 + '">' + post.tel2 + "</a>";
#
#               if ("" !== post.tel || "" !== post.tel2)
#                 estehtml += "<br/>";
#
#               if ("" !== post.fax)
#                 estehtml += '<i class="fas fa-fax"></i> ' + post.fax + "<br/>";
#
#               if ("" !== post.web)
#                 estehtml += '<i class="fa fa-link"></i> <a href="' + post.web + '" target="_blank" title="Enlace a ventana nueva">' + post.web + "</a><br>";
#
#               if ("" !== post.web2)
#                 estehtml += '<i class="fa fa-link"></i> <a href="' + post.web2 + '" target="_blank" title="Enlace a ventana nueva">' + post.web2 + "</a><br>";
#
#               if("" !== post.email)
#                 estehtml += '<i class="fa fa-envelope"></i> <a href="mailto:' + post.email + '" target="_blank" title="Enlace a ventana nueva">' + post.email + "</a><br>";
#
#               if ("" !== post.email2)
#                 estehtml += '<i class="fa fa-envelope"></i> <a href="mailto:' + post.email2 + '" target="_blank" title="Enlace a ventana nueva">' + post.email2 + "</a><br>";
#
#               estehtml += '</p></div><div class="col-sm-7"><div class="descripcion"><p>' + post.type + '</p><p>' + post.act_en + "</p>";
#
#               if ("" !== post.notas)
#                 estehtml += "<p>" + post.notes + "</p>";
#
#               estehtml += '</div></div><div class="col-sm-12"><div class="categorias"> CATEGORIES: ';
#               post.categorias.forEach(function(categ) {
#                   estehtml += '<a href="company-directory.html?id=' + categ.id + '#resultados" class="categoria">' + categ.categoria_en + '</a>&nbsp;';
#               });
#               estehtml += "</div></div></div></div>";
#
#               pDiv.innerHTML = estehtml;
#
#               pContain.appendChild(pDiv);
#             });
#           });
#         }
#     </script>
# <!--FINAL DE SCRIPTS-->
# <script>
#         window.RILEY_AGENT_ID = "daba2aad-1810-4ca3-9d90-37ff95df0153";
#         window.RILEY_API_URL = "https://www.rylei.ai";
#       </script>
# <script defer="" src="https://static.databutton.com/public/493604f5-5c06-4a6e-9381-0cf9e767d0bc/widget8.js"></script>
# <!--INICIO ESTADÍSTICAS  -->
# <script type="text/javascript">ma_codapp="filmmadrid";</script>
# <script src="/webutils/medicion_audiencias.js" type="text/javascript"></script>
# <!-- FIN ESTADÍSTICAS -->
# </body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.
#
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".
#
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %% [markdown]
# Para coger únicamente el texto de la etiqueta

# %%
soup.h1.get_text()
# Out:
# 'Companies Directory '

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
print(soup.h1)
print("")
print("Utilizando método .find()")
print(soup.find('h1'))
# Out:
# Sin utilizar método .find()
# <h1 class="display-1">Companies Directory </h1>
#
# Utilizando método .find()
# <h1 class="display-1">Companies Directory </h1>

# %% [markdown]
# Después de realizar lo anterior podemos pasar a extraer la información que queremos y crear el csv. Todas las columnas extraidas se muestran en los siguientes apartados.

# %% [markdown]
# Todos estas columnas vienen presentadas en los siguientes apartados:

# %% [markdown]
# ##### Obtener los nombres de las empresas

# %%
### Los añadimos a una lista
nombre_empresa = []

all_titles = soup.find_all(class_='col-12 resultado')
for title in all_titles:
    h3 = title.find('h3')  # Busca el h3 dentro del div
    if h3:
        nombre_empresa.append(h3.get_text(strip=True))

print(len(nombre_empresa))
print(nombre_empresa)
# Out:
# 15
# ['Cinema Republic, S.L.', 'Cinetel Multimedia, S.L.', 'Feel Sales (Content Line, S.L.)', 'Festimania Pictures S.L.', 'Inside Content, S.L.', 'Latido  Films (Latido Consorcio de Exportación del Cine Español, S.L.)', 'Mirror Audiovisual, S.L.', 'Moonrise Pictures', 'Sala 46 Films', 'Sala46 Films', 'Sogepaq - Video Mercury Films, S.A.', 'The Mediapro Studio Distribution', 'Treeline Distribution', 'Urban Films S.L.', 'Wanda Vision, S.A.']

# %%
# Creamos un DataFrame con los títulos, es decir una tabla 
# con sus columnas y filas
df = pd.DataFrame(nombre_empresa, columns=['Nombres de empresas'])
# Mostramos el DataFrame    
df
# Out:
#                                   Nombres de empresas
# 0                               Cinema Republic, S.L.
# 1                            Cinetel Multimedia, S.L.
# 2                     Feel Sales (Content Line, S.L.)
# 3                            Festimania Pictures S.L.
# 4                                Inside Content, S.L.
# 5   Latido  Films (Latido Consorcio de Exportación...
# 6                            Mirror Audiovisual, S.L.
# 7                                   Moonrise Pictures
# 8                                       Sala 46 Films
# 9                                        Sala46 Films
# 10                Sogepaq - Video Mercury Films, S.A.
# 11                   The Mediapro Studio Distribution
# 12                              Treeline Distribution
# 13                                   Urban Films S.L.
# 14                                 Wanda Vision, S.A.

# %% [markdown]
# ##### Obtener las direcciones

# %%
lista_direction = []

all_direction = soup.find_all(class_='col-sm-5')

for direction in all_direction:
    p = direction.find('p')
    if p:
        texto_completo = p.get_text(strip=True, separator="\n")  # reemplaza <br> por saltos de línea
        primera_linea = texto_completo.split('\n')[0]  # toma solo la primera línea
        lista_direction.append(primera_linea)
    else:
        lista_direction.append(None)

print(len(lista_direction))
lista_direction
# Out:
# 15
# ['Av. Rosario Manzaneque 25. 28250 Torrelodones',
#  'Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid',
#  'Av. Concha Espina, 65. 2º. 28016 Madrid',
#  'Arzobispo Morcillo, 40. 28029 Madrid',
#  'Francisco Navacerrada, 8, 5º. 28028 Madrid',
#  'San Bernardo, 20, 2º Of. 8. 28015 Madrid',
#  'Pico de la Miel, 47. 28023 Madrid',
#  'Santa Engracia, 108, 7th Floor. 28003 Madrid',
#  'C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid',
#  'C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid',
#  'Ana Mariscal, 7. Ciudad de la Imagen. 28223 Pozuelo de Alarcón',
#  'Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid',
#  'Castiello de Jaca 21B-6º1. 28050 Madrid',
#  'Viriato, 2. 4ª planta. 28010 Madrid',
#  'Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo de Alarcón']

# %%
df['Direcciones'] = lista_direction
df
# Out:
#                                   Nombres de empresas  \
# 0                               Cinema Republic, S.L.
# 1                            Cinetel Multimedia, S.L.
# 2                     Feel Sales (Content Line, S.L.)
# 3                            Festimania Pictures S.L.
# 4                                Inside Content, S.L.
# 5   Latido  Films (Latido Consorcio de Exportación...
# 6                            Mirror Audiovisual, S.L.
# 7                                   Moonrise Pictures
# 8                                       Sala 46 Films
# 9                                        Sala46 Films
# 10                Sogepaq - Video Mercury Films, S.A.
# 11                   The Mediapro Studio Distribution
# 12                              Treeline Distribution
# 13                                   Urban Films S.L.
# 14                                 Wanda Vision, S.A.
#
#                                           direcciones  \
# 0       Av. Rosario Manzaneque 25. 28250 Torrelodones
# 1      Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid
# 2             Av. Concha Espina, 65. 2º. 28016 Madrid
# 3                Arzobispo Morcillo, 40. 28029 Madrid
# 4          Francisco Navacerrada, 8, 5º. 28028 Madrid
# 5            San Bernardo, 20, 2º Of. 8. 28015 Madrid
# 6                   Pico de la Miel, 47. 28023 Madrid
# 7        Santa Engracia, 108, 7th Floor. 28003 Madrid
# 8      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid
# 9      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid
# 10  Ana Mariscal, 7. Ciudad de la Imagen. 28223 Po...
# 11    Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid
# 12            Castiello de Jaca 21B-6º1. 28050 Madrid
# 13                Viriato, 2. 4ª planta. 28010 Madrid
# 14  Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo...
#
#                                           Direcciones
# 0       Av. Rosario Manzaneque 25. 28250 Torrelodones
# 1      Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid
# 2             Av. Concha Espina, 65. 2º. 28016 Madrid
# 3                Arzobispo Morcillo, 40. 28029 Madrid
# 4          Francisco Navacerrada, 8, 5º. 28028 Madrid
# 5            San Bernardo, 20, 2º Of. 8. 28015 Madrid
# 6                   Pico de la Miel, 47. 28023 Madrid
# 7        Santa Engracia, 108, 7th Floor. 28003 Madrid
# 8      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid
# 9      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid
# 10  Ana Mariscal, 7. Ciudad de la Imagen. 28223 Po...
# 11    Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid
# 12            Castiello de Jaca 21B-6º1. 28050 Madrid
# 13                Viriato, 2. 4ª planta. 28010 Madrid
# 14  Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo...

# %%
df.drop(columns=['direcciones'], inplace=True)
df
# Out:
#                                   Nombres de empresas  \
# 0                               Cinema Republic, S.L.
# 1                            Cinetel Multimedia, S.L.
# 2                     Feel Sales (Content Line, S.L.)
# 3                            Festimania Pictures S.L.
# 4                                Inside Content, S.L.
# 5   Latido  Films (Latido Consorcio de Exportación...
# 6                            Mirror Audiovisual, S.L.
# 7                                   Moonrise Pictures
# 8                                       Sala 46 Films
# 9                                        Sala46 Films
# 10                Sogepaq - Video Mercury Films, S.A.
# 11                   The Mediapro Studio Distribution
# 12                              Treeline Distribution
# 13                                   Urban Films S.L.
# 14                                 Wanda Vision, S.A.
#
#                                           Direcciones
# 0       Av. Rosario Manzaneque 25. 28250 Torrelodones
# 1      Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid
# 2             Av. Concha Espina, 65. 2º. 28016 Madrid
# 3                Arzobispo Morcillo, 40. 28029 Madrid
# 4          Francisco Navacerrada, 8, 5º. 28028 Madrid
# 5            San Bernardo, 20, 2º Of. 8. 28015 Madrid
# 6                   Pico de la Miel, 47. 28023 Madrid
# 7        Santa Engracia, 108, 7th Floor. 28003 Madrid
# 8      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid
# 9      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid
# 10  Ana Mariscal, 7. Ciudad de la Imagen. 28223 Po...
# 11    Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid
# 12            Castiello de Jaca 21B-6º1. 28050 Madrid
# 13                Viriato, 2. 4ª planta. 28010 Madrid
# 14  Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo...

# %% [markdown]
# ##### Obtener los teléfonos

# %%
# Extraer los números de teléfono
lista_telefono = []

all_direction = soup.find_all(class_='col-sm-5')

for direction in all_direction:
    p = direction.find('p')
    if p:
        texto_completo = p.get_text(strip=True, separator="\n")
        lineas = texto_completo.split('\n')
        if len(lineas) > 1:
            lista_telefono.append(lineas[1])  # Segunda línea
        else:
            lista_telefono.append(None)
    else:
        lista_telefono.append(None)

print(len(lista_telefono))
lista_telefono
# Out:
# 15
# ['0034 91 856 55 01',
#  '0034 91 434 24 67',
#  '0034 91 590 39 20',
#  '0034 690 06 25 83',
#  '0034 91 831 33 56',
#  '0034 683 53 55 86',
#  '0034 610 445 583',
#  '0034 91 760 76 05',
#  '630950440',
#  '630950440',
#  '0034 91 512 02 00',
#  '0034 91 728 57 38',
#  '0034 981 22 47 76',
#  '0034 91 447 95 43',
#  '0034 91 352 83 76']

# %%
# Añadimos la columa precio al DataFrame
df['Teléfonos'] = lista_telefono
df
# Out:
#                                   Nombres de empresas  \
# 0                               Cinema Republic, S.L.
# 1                            Cinetel Multimedia, S.L.
# 2                     Feel Sales (Content Line, S.L.)
# 3                            Festimania Pictures S.L.
# 4                                Inside Content, S.L.
# 5   Latido  Films (Latido Consorcio de Exportación...
# 6                            Mirror Audiovisual, S.L.
# 7                                   Moonrise Pictures
# 8                                       Sala 46 Films
# 9                                        Sala46 Films
# 10                Sogepaq - Video Mercury Films, S.A.
# 11                   The Mediapro Studio Distribution
# 12                              Treeline Distribution
# 13                                   Urban Films S.L.
# 14                                 Wanda Vision, S.A.
#
#                                           Direcciones          Teléfonos
# 0       Av. Rosario Manzaneque 25. 28250 Torrelodones  0034 91 856 55 01
# 1      Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid  0034 91 434 24 67
# 2             Av. Concha Espina, 65. 2º. 28016 Madrid  0034 91 590 39 20
# 3                Arzobispo Morcillo, 40. 28029 Madrid  0034 690 06 25 83
# 4          Francisco Navacerrada, 8, 5º. 28028 Madrid  0034 91 831 33 56
# 5            San Bernardo, 20, 2º Of. 8. 28015 Madrid  0034 683 53 55 86
# 6                   Pico de la Miel, 47. 28023 Madrid   0034 610 445 583
# 7        Santa Engracia, 108, 7th Floor. 28003 Madrid  0034 91 760 76 05
# 8      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid          630950440
# 9      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid          630950440
# 10  Ana Mariscal, 7. Ciudad de la Imagen. 28223 Po...  0034 91 512 02 00
# 11    Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid  0034 91 728 57 38
# 12            Castiello de Jaca 21B-6º1. 28050 Madrid  0034 981 22 47 76
# 13                Viriato, 2. 4ª planta. 28010 Madrid  0034 91 447 95 43
# 14  Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo...  0034 91 352 83 76

# %% [markdown]
# ##### Obtener los url de cada empresa

# %%
# Extraer los correos electrónicos
lista_url = []

all_direction = soup.find_all(class_='col-sm-5')

for direction in all_direction:
    p = direction.find('p')
    if p:
        texto_completo = p.get_text(strip=True, separator="\n")
        lineas = texto_completo.split('\n')
        
        # Buscar línea que contenga 'http'
        url_linea = next((linea for linea in lineas if 'http' in linea), None)
        lista_url.append(url_linea)
    else:
        lista_url.append(None)

print(len(lista_url))
lista_url
# Out:
# 15
# ['http://www.cinemarepublic.es/',
#  'http://www.cinetelmultimedia.com/',
#  'http://www.feelsales.com/',
#  'http://www.festimania.com/',
#  'http://www.insidecontent.tv/',
#  'http://www.latidofilms.com/',
#  'http://mirroraudiovisual.es/',
#  'http://www.moonrisepictures.eu/',
#  'http://sala46.com/',
#  'http://sala46.com/',
#  'http://www.sogepaq.es/',
#  'https://distribution.themediaprostudio.com/',
#  'http://www.treelinedistribution.com',
#  'http://www.urbanfilms.es/',
#  'http://www.wanda.es/']

# %%
# Añadimos la columa precio al DataFrame
df['Página Web'] = lista_url
df
# Out:
#                                   Nombres de empresas  \
# 0                               Cinema Republic, S.L.
# 1                            Cinetel Multimedia, S.L.
# 2                     Feel Sales (Content Line, S.L.)
# 3                            Festimania Pictures S.L.
# 4                                Inside Content, S.L.
# 5   Latido  Films (Latido Consorcio de Exportación...
# 6                            Mirror Audiovisual, S.L.
# 7                                   Moonrise Pictures
# 8                                       Sala 46 Films
# 9                                        Sala46 Films
# 10                Sogepaq - Video Mercury Films, S.A.
# 11                   The Mediapro Studio Distribution
# 12                              Treeline Distribution
# 13                                   Urban Films S.L.
# 14                                 Wanda Vision, S.A.
#
#                                           Direcciones          Teléfonos  \
# 0       Av. Rosario Manzaneque 25. 28250 Torrelodones  0034 91 856 55 01
# 1      Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid  0034 91 434 24 67
# 2             Av. Concha Espina, 65. 2º. 28016 Madrid  0034 91 590 39 20
# 3                Arzobispo Morcillo, 40. 28029 Madrid  0034 690 06 25 83
# 4          Francisco Navacerrada, 8, 5º. 28028 Madrid  0034 91 831 33 56
# 5            San Bernardo, 20, 2º Of. 8. 28015 Madrid  0034 683 53 55 86
# 6                   Pico de la Miel, 47. 28023 Madrid   0034 610 445 583
# 7        Santa Engracia, 108, 7th Floor. 28003 Madrid  0034 91 760 76 05
# 8      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid          630950440
# 9      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid          630950440
# 10  Ana Mariscal, 7. Ciudad de la Imagen. 28223 Po...  0034 91 512 02 00
# 11    Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid  0034 91 728 57 38
# 12            Castiello de Jaca 21B-6º1. 28050 Madrid  0034 981 22 47 76
# 13                Viriato, 2. 4ª planta. 28010 Madrid  0034 91 447 95 43
# 14  Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo...  0034 91 352 83 76
#
#                                      Página Web
# 0                 http://www.cinemarepublic.es/
# 1             http://www.cinetelmultimedia.com/
# 2                     http://www.feelsales.com/
# 3                    http://www.festimania.com/
# 4                  http://www.insidecontent.tv/
# 5                   http://www.latidofilms.com/
# 6                  http://mirroraudiovisual.es/
# 7               http://www.moonrisepictures.eu/
# 8                            http://sala46.com/
# 9                            http://sala46.com/
# 10                       http://www.sogepaq.es/
# 11  https://distribution.themediaprostudio.com/
# 12          http://www.treelinedistribution.com
# 13                    http://www.urbanfilms.es/
# 14                         http://www.wanda.es/

# %% [markdown]
# ##### Obtener los correos electrónicos

# %%
# Extarer los correos electrónicos
lista_email = []
all_direction = soup.find_all(class_='col-sm-5')
for direction in all_direction:
    p = direction.find('p')
    if p:
        texto_completo = p.get_text(strip=True, separator="\n")
        lineas = texto_completo.split('\n')
        
        # Buscar línea que contenga '@'
        email_linea = next((linea for linea in lineas if '@' in linea), None)
        lista_email.append(email_linea)
    else:
        lista_email.append(None)
lista_email
# Out:
# ['david@cinemarepublic.es',
#  'jmjara@cinetelmultimedia.com',
#  'info@feelsales.com',
#  'info@festimania.com',
#  'contact@insidecontent.tv',
#  'latido@latidofilms.com',
#  'mrezola@mirroraudiovisual.es',
#  'info@moonrisepictures.eu',
#  'films@sala46.com',
#  'films@sala46.com',
#  'smacmahon@videomercury.com',
#  'themediaprostudio@mediapro.tv',
#  'luisa.romeo@treelinedistribution.com',
#  'info@urbanfilms.es',
#  'wanda@wanda.es']

# %%
df['Correos electrónico']= lista_email
df
# Out:
#                                   Nombres de empresas  \
# 0                               Cinema Republic, S.L.
# 1                            Cinetel Multimedia, S.L.
# 2                     Feel Sales (Content Line, S.L.)
# 3                            Festimania Pictures S.L.
# 4                                Inside Content, S.L.
# 5   Latido  Films (Latido Consorcio de Exportación...
# 6                            Mirror Audiovisual, S.L.
# 7                                   Moonrise Pictures
# 8                                       Sala 46 Films
# 9                                        Sala46 Films
# 10                Sogepaq - Video Mercury Films, S.A.
# 11                   The Mediapro Studio Distribution
# 12                              Treeline Distribution
# 13                                   Urban Films S.L.
# 14                                 Wanda Vision, S.A.
#
#                                           Direcciones          Teléfonos  \
# 0       Av. Rosario Manzaneque 25. 28250 Torrelodones  0034 91 856 55 01
# 1      Ángel Ganivet, 28. Portal 4, 5ºA. 28007 Madrid  0034 91 434 24 67
# 2             Av. Concha Espina, 65. 2º. 28016 Madrid  0034 91 590 39 20
# 3                Arzobispo Morcillo, 40. 28029 Madrid  0034 690 06 25 83
# 4          Francisco Navacerrada, 8, 5º. 28028 Madrid  0034 91 831 33 56
# 5            San Bernardo, 20, 2º Of. 8. 28015 Madrid  0034 683 53 55 86
# 6                   Pico de la Miel, 47. 28023 Madrid   0034 610 445 583
# 7        Santa Engracia, 108, 7th Floor. 28003 Madrid  0034 91 760 76 05
# 8      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid          630950440
# 9      C/ Vinaroz 31, escalera izq. 3ºB. 28002 Madrid          630950440
# 10  Ana Mariscal, 7. Ciudad de la Imagen. 28223 Po...  0034 91 512 02 00
# 11    Ctra. Fuencarral a Alcobendas, 24. 28049 Madrid  0034 91 728 57 38
# 12            Castiello de Jaca 21B-6º1. 28050 Madrid  0034 981 22 47 76
# 13                Viriato, 2. 4ª planta. 28010 Madrid  0034 91 447 95 43
# 14  Avda. Europa, 16 - Chalet 1 y 2. 28224 Pozuelo...  0034 91 352 83 76
#
#                                      Página Web  \
# 0                 http://www.cinemarepublic.es/
# 1             http://www.cinetelmultimedia.com/
# 2                     http://www.feelsales.com/
# 3                    http://www.festimania.com/
# 4                  http://www.insidecontent.tv/
# 5                   http://www.latidofilms.com/
# 6                  http://mirroraudiovisual.es/
# 7               http://www.moonrisepictures.eu/
# 8                            http://sala46.com/
# 9                            http://sala46.com/
# 10                       http://www.sogepaq.es/
# 11  https://distribution.themediaprostudio.com/
# 12          http://www.treelinedistribution.com
# 13                    http://www.urbanfilms.es/
# 14                         http://www.wanda.es/
#
#                      Correos electrónico
# 0                david@cinemarepublic.es
# 1           jmjara@cinetelmultimedia.com
# 2                     info@feelsales.com
# 3                    info@festimania.com
# 4               contact@insidecontent.tv
# 5                 latido@latidofilms.com
# 6           mrezola@mirroraudiovisual.es
# 7               info@moonrisepictures.eu
# 8                       films@sala46.com
# 9                       films@sala46.com
# 10            smacmahon@videomercury.com
# 11         themediaprostudio@mediapro.tv
# 12  luisa.romeo@treelinedistribution.com
# 13                    info@urbanfilms.es
# 14                        wanda@wanda.es

# %% [markdown]
# ##### Descarga de la tabla de datos
#
# Finalmente descargamos la tabla anterior en un csv.

# %%
#Descargar el DataFrame a un archivo CSV
df.to_csv('empresas_madrid.csv', index=False, encoding='utf-8-sig')
